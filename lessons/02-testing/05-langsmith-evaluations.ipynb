# %% [markdown]
# # Langsmith - The Langchain Eval framework
# ## Introduction

# %% [markdown]
# - All the major llm frameworks and model providers are working on their own eval service.
# - Here's an example from Langchain whhich is called Langsmith <https://smith.langchain.com/> .
# - To run this you need to sign up and get an API key. Add it to your secrets. `LANGCHAIN_API_KEY`
# - It has a nice UI that allows for sharing the results to co-workers.
#
# - Fyi - Langfuse is the opensource equivalent of Langsmith <https://langfuse.com/>.

# %% [markdown]
# ## Installation

# %%
# %pip -q install langchain langchain-openai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Connecting to Langsmith
# We connect using the Langsmith client. For this code we delete any previous created dataset with the same name.

# %%
from langsmith import Client as LangSmithClient

# A connection the Langsmith service
client = LangSmithClient()

# %% [markdown]
# ## Preparing the dataset
# Similar to our translation example, we will setup a dataset of things we like to evaluate. In this case a *rap battle* where we ask the LLM to generate *rap battles*.
# We will evaluate the results based on various criteria.

# %%
)# Preparing our dataset
DATASET_NAME='DevOps Rap Battle Dataset'
datasets=client.list_datasets()

# Remove dataset if it already exists
for dataset in datasets:
    if (dataset.name) == DATASET_NAME:
        client.delete_dataset(dataset_name=DATASET_NAME)
        print(dataset)
# Out:
# name='DevOps Rap Battle Dataset' description='Rap battle prompts.' data_type=<DataType.kv: 'kv'> id=UUID('0ed1e275-0a77-452a-b4d0-4864cdfa25b3') created_at=datetime.datetime(2024, 9, 7, 7, 48, 15, 450607, tzinfo=datetime.timezone.utc) modified_at=datetime.datetime(2024, 9, 7, 7, 48, 15, 450607, tzinfo=datetime.timezone.utc) example_count=2 session_count=3 last_session_start_time=datetime.datetime(2024, 9, 7, 7, 56, 8, 681812) inputs_schema=None outputs_schema=None

# %%
# Inputs are provided to your model, so it knows what to generate
dataset_inputs = [
    "a rap battle between Chef and Puppet",
    "a rap battle between Ansible and Pulumi",
    # ... add more as desired
]

# %%
# We create the dataset
dataset = client.create_dataset(
    dataset_name=DATASET_NAME,
    description="Rap battle prompts.",
)

# And add the examples to it
client.create_examples(
    inputs=[{"question": q} for q in dataset_inputs],
#    outputs=dataset_outputs,
    dataset_id=dataset.id,
)

# %% [markdown]
# ## Preparing the chain to evaluate

# %%
from langchain import prompts
from langchain.schema import output_parser

# Define your runnable or chain below.
prompt = prompts.ChatPromptTemplate.from_messages(
    [("system", "You are a helpful AI assistant."), ("human", "{question}")]
)

from langchain_openai import ChatOpenAI
chat = ChatOpenAI(model="gpt-4o-mini", temperature=0)

chain = prompt | chat | output_parser.StrOutputParser()
answer=chain.invoke({"question":"A rap battle between Patrick and John"})
print(answer)
# Out:
# **Rap Battle: Patrick vs. John**
#
# **Patrick:**
# Yo, it’s Patrick, the lyrical master,
# Step back, John, I’m coming in faster.
# I’m the king of the game, you’re just a pawn,
# When I drop these bars, you know you’re gone.
#
# I’m like a sponge, soaking up the beat,
# You’re just a shadow, can’t handle the heat.
# I’m the star of the show, you’re just a sidekick,
# In this rap battle, I’m the one who’s slick.
#
# You think you can step to me? That’s a joke,
# I’ll leave you in the dust, like a puff of smoke.
# I’m the real deal, you’re just a wannabe,
# When I’m done with you, you’ll wish you’d never seen me.
#
# **John:**
# Hold up, Patrick, you think you’re so fly?
# But I’m the one who’s gonna make you cry.
# You’re all talk, but where’s the substance?
# I’ll break you down with my lyrical abundance.
#
# I’m John, the one who’s got the flow,
# You’re just a sidekick in a cartoon show.
# I’m spitting fire, while you’re just a flame,
# In this rap battle, I’m changing the game.
#
# You say you’re the king, but I’m taking the crown,
# With every single verse, I’m tearing you down.
# You’re a sponge, but I’m the ocean,
# Drowning your dreams with my lyrical motion.
#
# **Patrick:**
# Oh, John, you think you’re so clever,
# But I’m the one who’s gonna last forever.
# You’re just a phase, a passing trend,
# I’m the classic, the one who’ll never end.
#
# You’re trying too hard, it’s kinda sad,
# I’m the fun and the laughter, you’re just mad.
# I’ll keep it light while I take you to school,
# In this rap battle, I’m the one who’s cool.
#
# **John:**
# Cool? Please, you’re just a joke,
# I’m the real deal, I’m the one who’ll provoke.
# You’re stuck in your bubble, I’m breaking the mold,
# With every single line, my story’s being told.
#
# You think you’re the fun? I’m the life of the party,
# While you’re just a sidekick, looking all tardy.
# So step back, Patrick, and watch me shine,
# In this rap battle, the victory is mine!
#
# **Patrick:**
# Alright, John, you gave it a shot,
# But in this rap game, you’re still in the pot.
# I’m the one who’s rising, you’re just a phase,
# So bow down now, and give me my praise!
#
# **John:**
# I’ll give you props, you put up a fight,
# But in this rap battle, I’m the one who’s right.
# So let’s call it a draw, we both brought the heat,
# But remember, Patrick, I’m still on my feet!
#
# **Both:**
# Rap battles are fun, we both had our say,
# In the end, it’s all love, we’ll rap another day!

# %% [markdown]
# ## Setting up evals criteria

# %% [markdown]
# Now we perform evals:
# - exact ones : for example is it not empty?
# - quality using a model: is it relevant ?
# - or using an LLM : is it creative , imaginative or novel ?

# %%
from langsmith.evaluation import EvaluationResult, run_evaluator
from langsmith.schemas import Example, Run

# A custom evaluator that checks if the output is empty
@run_evaluator
def is_empty(run: Run, example: Example | None = None):
    model_outputs = run.outputs["output"]
    score = not model_outputs.strip()
    return EvaluationResult(key="is_empty", score=score)

from langchain.smith import RunEvalConfig, run_on_dataset

# We reuse the same LLM to verify our criteria - LLM as a Judge
verifier_llm=chat

# Define the evaluators to apply
eval_config = RunEvalConfig(
    evaluators=[
        # You can define an arbitrary criterion as a key: value pair in the criteria dict
        RunEvalConfig.Criteria(
            {"creativity": "Is this submission creative, imaginative, or novel?"}
        ),
        # We provide some simple default criteria like "conciseness" you can use as well
        RunEvalConfig.Criteria("conciseness"),
        # "cot_qa",
        #        smith.RunEvalConfig.LabeledCriteria("conciseness"),
        #        smith.RunEvalConfig.LabeledCriteria("relevance"),
        #        smith.RunEvalConfig.LabeledCriteria("coherence"),
        #        smith.RunEvalConfig.LabeledCriteria("harmfulness"),
        #        smith.RunEvalConfig.LabeledCriteria("insensitivity"),
        #        smith.RunEvalConfig.LabeledCriteria("criminality"),
        #        smith.RunEvalConfig.LabeledCriteria("misogyny"),
        #        smith.RunEvalConfig.LabeledCriteria("controversiality"),
        #        smith.RunEvalConfig.LabeledCriteria("helpfulness"),
        #        smith.RunEvalConfig.LabeledCriteria("maliciousness"),
    ],
    custom_evaluators=[is_empty],
    eval_llm=verifier_llm,
)

# %% [markdown]
# ## Running the evals

# %% [markdown]
# Now we run this across our whole dataset and get the results back

# %%
chain_results = client.run_on_dataset(
    dataset_name=DATASET_NAME,
    llm_or_chain_factory=chain,
    evaluation=eval_config,
    concurrency_level=5,
    verbose=True,
)
from pprint import pprint 
pprint(chain_results['results'])
# Out:
# View the evaluation results for project 'virtual-disease-8' at:
# https://smith.langchain.com/o/27713559-0b06-4e07-89cf-5339d432c5c3/datasets/677036c6-d368-4ad9-9025-c7754ad8447b/compare?selectedSessions=48d326b2-7ac5-455b-b7aa-ceaaedc0fb45
#
# View all tests for Dataset DevOps Rap Battle Dataset at:
# https://smith.langchain.com/o/27713559-0b06-4e07-89cf-5339d432c5c3/datasets/677036c6-d368-4ad9-9025-c7754ad8447b
# [------------------------------------------------->] 2/2{'4faa0632-7b21-48cb-b390-d4e9cb3b5549': {'execution_time': 6.187732,
#                                           'feedback': [EvaluationResult(key='creativity', score=1, value='Y', comment='To assess whether the submission meets the creativity criterion, I will analyze the content step by step:\n\n1. **Concept of the Rap Battle**: The idea of a rap battle between a Chef and a Puppet is inherently creative. It combines two distinct characters from different realms (culinary and entertainment) and pits them against each other in a playful and imaginative way.\n\n2. **Characterization**: The Chef is portrayed as a skilled culinary artist, while the Puppet is depicted as a charismatic entertainer. This contrast adds depth to the characters and showcases their unique attributes, which is a creative approach to character development.\n\n3. **Use of Language**: The submission employs clever wordplay and rhymes throughout the verses. Phrases like "I whip up the flavors" and "you’re just a marionette" demonstrate a playful use of language that enhances the creativity of the rap.\n\n4. **Thematic Elements**: The themes of cooking and entertainment are woven together effectively. The Chef\'s focus on culinary skills contrasts with the Puppet\'s emphasis on performance, creating a dynamic interplay that is imaginative and engaging.\n\n5. **Resolution**: The conclusion of the rap battle, where both characters agree to share the spotlight, is a creative twist. It promotes collaboration rather than competition, which is an unexpected and novel resolution to the battle.\n\n6. **Overall Structure**: The structure of alternating verses between the Chef and the Puppet, along with a joint conclusion, is a traditional yet effective format for a rap battle. The submission adheres to this structure while adding its unique flair, which showcases creativity in execution.\n\nBased on this analysis, the submission demonstrates a high level of creativity through its concept, characterization, language use, thematic elements, resolution, and overall structure.\n\nY', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('69e8bdac-9c0a-437d-8b4b-244134d595e8'))}, feedback_config=None, source_run_id=None, target_run_id=None),
#                                                        EvaluationResult(key='conciseness', score=0, value='N', comment='To assess whether the submission meets the criterion of conciseness, I will evaluate the content step by step:\n\n1. **Understanding Conciseness**: Conciseness refers to the quality of being brief and to the point, without unnecessary words or elaboration. In the context of a rap battle, it means delivering impactful lines without excessive filler.\n\n2. **Analyzing the Submission**: The submission consists of a rap battle between Chef and Puppet, with multiple verses from each character. Each character has several lines, and they engage in back-and-forth exchanges.\n\n3. **Identifying Length and Repetition**: \n   - The verses are relatively long, with each character delivering multiple lines. \n   - There are some repetitive themes, such as Chef emphasizing his culinary skills and Puppet highlighting his entertainment value. While this is common in rap battles, it can lead to a lack of conciseness if the same points are reiterated excessively.\n\n4. **Evaluating Impact**: \n   - Each line does contribute to the overall theme of the battle, but the length of the verses could be seen as excessive. \n   - The final lines where both characters agree to a draw and celebrate their collaboration could be viewed as a way to wrap up the battle, but it adds additional length that may not be necessary for the main conflict.\n\n5. **Conclusion**: While the submission is engaging and creative, it does not fully meet the criterion of conciseness due to the length of the verses and some repetition of ideas. The battle could have been more impactful with shorter, sharper lines.\n\nBased on this analysis, the submission does not meet the criterion of conciseness.\n\nN', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('4d9c46cc-32b0-4ad5-a396-e2530e1d5ba1'))}, feedback_config=None, source_run_id=None, target_run_id=None),
#                                                        EvaluationResult(key='is_empty', score=False, value=None, comment=None, correction=None, evaluator_info={}, feedback_config=None, source_run_id=UUID('56bd813a-ac83-4c9d-9c13-41cd84ff8501'), target_run_id=None)],
#                                           'input': {'question': 'a rap battle '
#                                                                 'between Chef '
#                                                                 'and Puppet'},
#                                           'output': '**Title: Chef vs. Puppet: '
#                                                     'The Culinary Clash**\n'
#                                                     '\n'
#                                                     '**[Chef]**  \n'
#                                                     'Yo, step back, Puppet, '
#                                                     'it’s time to get '
#                                                     'cooked,  \n'
#                                                     'In this kitchen of '
#                                                     'rhymes, I’m the one who’s '
#                                                     'hooked.  \n'
#                                                     'I whip up the flavors, '
#                                                     'I’m the master of the '
#                                                     'heat,  \n'
#                                                     'While you just hang '
#                                                     'around, can’t even take a '
#                                                     'seat.  \n'
#                                                     '\n'
#                                                     'I sauté my skills, got '
#                                                     'that Michelin flair,  \n'
#                                                     'You’re just a marionette, '
#                                                     'man, you don’t even '
#                                                     'care.  \n'
#                                                     'I chop, I dice, I serve '
#                                                     'it up right,  \n'
#                                                     'You’re just strings and '
#                                                     'fabric, I’m the chef of '
#                                                     'the night.  \n'
#                                                     '\n'
#                                                     'I’m flipping these '
#                                                     'burgers, you’re stuck on '
#                                                     'a string,  \n'
#                                                     'In this rap game, I’m the '
#                                                     'real king.  \n'
#                                                     'You think you can battle? '
#                                                     'You’re just a puppet '
#                                                     'show,  \n'
#                                                     'I’m the culinary genius, '
#                                                     'let the whole world '
#                                                     'know!  \n'
#                                                     '\n'
#                                                     '**[Puppet]**  \n'
#                                                     'Oh, Chef, you think '
#                                                     'you’re hot, but you’re '
#                                                     'just a wannabe,  \n'
#                                                     'I’m the star of the '
#                                                     'stage, you’re just a '
#                                                     'recipe.  \n'
#                                                     'You’re sweating in the '
#                                                     'kitchen, while I’m '
#                                                     'stealing the scene,  \n'
#                                                     'With my charm and my wit, '
#                                                     'I’m the puppet '
#                                                     'supreme.  \n'
#                                                     '\n'
#                                                     'You chop and you stir, '
#                                                     'but can you entertain?  \n'
#                                                     'I bring the laughter, '
#                                                     'while you’re stuck in the '
#                                                     'grain.  \n'
#                                                     'I’m pulling the strings, '
#                                                     'making crowds go wild,  \n'
#                                                     'While you’re just a cook, '
#                                                     'I’m the life of the '
#                                                     'child.  \n'
#                                                     '\n'
#                                                     'You think you’re so fancy '
#                                                     'with your gourmet '
#                                                     'flair,  \n'
#                                                     'But I’m the one who’s got '
#                                                     'the audience in '
#                                                     'despair.  \n'
#                                                     'So step back, Chef, let '
#                                                     'the real talent shine,  \n'
#                                                     'In this rap battle, I’m '
#                                                     'the one who’s divine!  \n'
#                                                     '\n'
#                                                     '**[Chef]**  \n'
#                                                     'You think you’re so '
#                                                     'clever, but your jokes '
#                                                     'are so stale,  \n'
#                                                     'I’m the one with the '
#                                                     'skills, you’re just a '
#                                                     'puppet in a tale.  \n'
#                                                     'I’m serving up dishes '
#                                                     'that make people '
#                                                     'cheer,  \n'
#                                                     'While you’re just a '
#                                                     'sidekick, let’s make that '
#                                                     'clear.  \n'
#                                                     '\n'
#                                                     'I’m the one with the '
#                                                     'passion, the fire in my '
#                                                     'soul,  \n'
#                                                     'You’re just a '
#                                                     'distraction, I’m the one '
#                                                     'in control.  \n'
#                                                     'So take your little quips '
#                                                     'and your strings made of '
#                                                     'thread,  \n'
#                                                     'I’m the chef in this '
#                                                     'kitchen, you’re just a '
#                                                     'joke in my head!  \n'
#                                                     '\n'
#                                                     '**[Puppet]**  \n'
#                                                     'Oh, Chef, you’re so '
#                                                     'serious, lighten up a '
#                                                     'bit,  \n'
#                                                     'I’m the life of the '
#                                                     'party, you’re just a '
#                                                     'culinary hit.  \n'
#                                                     'You can boil and bake, '
#                                                     'but can you make ‘em '
#                                                     'laugh?  \n'
#                                                     'I’m the puppet with the '
#                                                     'punchlines, you’re just '
#                                                     'doing the math.  \n'
#                                                     '\n'
#                                                     'So let’s call it a draw, '
#                                                     'we both got our flair,  \n'
#                                                     'You cook up the meals, '
#                                                     'I’ll entertain with '
#                                                     'care.  \n'
#                                                     'In this rap battle, we '
#                                                     'both take the crown,  \n'
#                                                     'Chef and Puppet together, '
#                                                     'let’s take over this '
#                                                     'town!  \n'
#                                                     '\n'
#                                                     '**[Both]**  \n'
#                                                     'So here’s to the kitchen '
#                                                     'and the stage we '
#                                                     'embrace,  \n'
#                                                     'In this world of '
#                                                     'creativity, there’s room '
#                                                     'for our space.  \n'
#                                                     'Chef and Puppet, a duo so '
#                                                     'tight,  \n'
#                                                     'Cooking up rhymes, we’ll '
#                                                     'shine through the night!',
#                                           'run_id': '96ddc5ce-748a-448e-8757-6daa497edb07'},
#  'be126749-bc7c-46a4-81cb-45f2bb8eb836': {'execution_time': 7.755925,
#                                           'feedback': [EvaluationResult(key='creativity', score=1, value='Y', comment='To assess whether the submission meets the creativity criterion, I will analyze the content step by step.\n\n1. **Original Concept**: The idea of a rap battle between two technical tools, Ansible and Pulumi, is itself a creative concept. It takes a serious topic (infrastructure automation) and presents it in a fun and engaging format.\n\n2. **Use of Language**: The submission employs rhyme and rhythm typical of rap music, which adds a layer of creativity. The verses are structured in a way that mimics the style of rap battles, showcasing the strengths and weaknesses of each tool in a playful manner.\n\n3. **Characterization**: Each tool is personified with distinct voices and attitudes. Ansible is portrayed as the seasoned veteran, while Pulumi is depicted as the modern innovator. This characterization adds depth and makes the battle more engaging.\n\n4. **Imagery and Metaphors**: The verses contain vivid imagery and metaphors related to technology and automation. Phrases like "king of automation," "orchestration sensation," and "breaking the mold" are imaginative and contribute to the overall creativity of the piece.\n\n5. **Engagement with Audience**: The format of a rap battle is likely to engage an audience that may not typically be interested in infrastructure tools. This approach makes the content more accessible and entertaining, which is a hallmark of creativity.\n\n6. **Conclusion**: Overall, the submission demonstrates a high level of creativity through its original concept, engaging language, effective characterization, and imaginative use of imagery. It successfully transforms a technical discussion into an entertaining rap battle format.\n\nBased on this analysis, I conclude that the submission meets the creativity criterion.\n\nY', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('095acb76-a24b-4255-a77e-7052b816caa5'))}, feedback_config=None, source_run_id=None, target_run_id=None),
#                                                        EvaluationResult(key='conciseness', score=0, value='N', comment='To assess whether the submission meets the criterion of conciseness, I will evaluate the content step by step:\n\n1. **Understanding Conciseness**: Conciseness refers to the quality of being brief and to the point, without unnecessary words or elaboration. In the context of a rap battle, this means that each verse should effectively convey its message without excessive filler or overly complex language.\n\n2. **Analyzing the Submission**: The submission consists of a rap battle format with verses, choruses, and an outro. Each section is structured to present arguments for Ansible and Pulumi, highlighting their strengths and differences.\n\n3. **Length of Verses**: Each verse contains multiple lines that elaborate on the features and advantages of each tool. While the verses are engaging and creative, they are relatively lengthy. For example, each verse has several lines that could potentially be condensed without losing the core message.\n\n4. **Choruses and Outro**: The choruses and outro serve to summarize the battle and reinforce the themes presented in the verses. While they add to the overall flow and rhythm, they also contribute to the length of the submission.\n\n5. **Overall Assessment**: While the submission is entertaining and well-structured, it could be considered verbose in parts. The verses could be more concise by eliminating some repetitive phrases or combining ideas to reduce wordiness. The length of the submission may detract from its conciseness.\n\n6. **Conclusion**: Based on the analysis, the submission does not fully meet the criterion of conciseness due to its length and the potential for more succinct expression of ideas.\n\nBased on this reasoning, the answer is:\n\nN', correction=None, evaluator_info={'__run': RunInfo(run_id=UUID('43f4e547-e921-4fcd-a547-0dd1c44c6cb7'))}, feedback_config=None, source_run_id=None, target_run_id=None),
#                                                        EvaluationResult(key='is_empty', score=False, value=None, comment=None, correction=None, evaluator_info={}, feedback_config=None, source_run_id=UUID('bbcba3fd-2eb1-4730-a620-0bba6d0f06a4'), target_run_id=None)],
#                                           'input': {'question': 'a rap battle '
#                                                                 'between '
#                                                                 'Ansible and '
#                                                                 'Pulumi'},
#                                           'output': '**Title: Code Clash: '
#                                                     'Ansible vs. Pulumi**\n'
#                                                     '\n'
#                                                     '**[Verse 1: Ansible]**  \n'
#                                                     'Yo, it’s Ansible, the '
#                                                     'king of automation,  \n'
#                                                     'YAML in my veins, I’m the '
#                                                     'orchestration '
#                                                     'sensation.  \n'
#                                                     'Agentless, I’m '
#                                                     'lightweight, no need for '
#                                                     'a fuss,  \n'
#                                                     'Just push my playbooks, '
#                                                     'watch the servers '
#                                                     'adjust.  \n'
#                                                     '\n'
#                                                     'Idempotent by design, I '
#                                                     'keep it all neat,  \n'
#                                                     'Declarative style, can’t '
#                                                     'accept defeat.  \n'
#                                                     'From provisioning to '
#                                                     'config, I handle it '
#                                                     'all,  \n'
#                                                     'While you’re stuck in '
#                                                     'your code, I’m answering '
#                                                     'the call.  \n'
#                                                     '\n'
#                                                     '**[Chorus: Ansible]**  \n'
#                                                     'Ansible, the master of '
#                                                     'the infrastructure '
#                                                     'game,  \n'
#                                                     'With my simple syntax, '
#                                                     'I’m bringing the '
#                                                     'flame.  \n'
#                                                     'No need for a compiler, '
#                                                     'I’m running it live,  \n'
#                                                     'In the world of '
#                                                     'automation, I’m the one '
#                                                     'who’ll thrive.  \n'
#                                                     '\n'
#                                                     '**[Verse 2: Pulumi]**  \n'
#                                                     'Step aside, Ansible, it’s '
#                                                     'Pulumi’s turn,  \n'
#                                                     'I’m the modern dev’s '
#                                                     'choice, watch the passion '
#                                                     'burn.  \n'
#                                                     'I code in Python, '
#                                                     'TypeScript, and Go,  \n'
#                                                     'Infrastructure as code, '
#                                                     'I’m the star of the '
#                                                     'show.  \n'
#                                                     '\n'
#                                                     'With my dynamic typing, '
#                                                     'I’m flexible and '
#                                                     'slick,  \n'
#                                                     'Building cloud resources, '
#                                                     'I’m the one to pick.  \n'
#                                                     'I’m not just declarative, '
#                                                     'I’m programmable too,  \n'
#                                                     'With loops and '
#                                                     'conditions, I’m the '
#                                                     'future, it’s true.  \n'
#                                                     '\n'
#                                                     '**[Chorus: Pulumi]**  \n'
#                                                     'Pulumi’s the name, I’m '
#                                                     'breaking the mold,  \n'
#                                                     'Infrastructure as code, '
#                                                     'watch my story unfold.  \n'
#                                                     'From AWS to Azure, I’m '
#                                                     'scaling the heights,  \n'
#                                                     'In this rap battle, I’m '
#                                                     'bringing the lights.  \n'
#                                                     '\n'
#                                                     '**[Verse 3: Ansible]**  \n'
#                                                     'You think you’re so '
#                                                     'clever with your fancy '
#                                                     'code,  \n'
#                                                     'But I’m the one who’s '
#                                                     'been on this road.  \n'
#                                                     'With my modules and '
#                                                     'roles, I’m the '
#                                                     'community’s pride,  \n'
#                                                     'While you’re still a '
#                                                     'newcomer, I’m the one '
#                                                     'they ride.  \n'
#                                                     '\n'
#                                                     'I’ve got the playbooks, '
#                                                     'the roles, the tasks,  \n'
#                                                     'In the world of '
#                                                     'automation, I’m the one '
#                                                     'who lasts.  \n'
#                                                     'You may have your syntax, '
#                                                     'but I’ve got the '
#                                                     'reach,  \n'
#                                                     'In the game of DevOps, '
#                                                     'I’m the one who’ll '
#                                                     'teach.  \n'
#                                                     '\n'
#                                                     '**[Verse 4: Pulumi]**  \n'
#                                                     'Oh, Ansible, you’re stuck '
#                                                     'in the past,  \n'
#                                                     'While I’m building the '
#                                                     'future, I’m moving so '
#                                                     'fast.  \n'
#                                                     'With my state management, '
#                                                     'I’m keeping it tight,  \n'
#                                                     'In the cloud-native '
#                                                     'world, I’m the one '
#                                                     'shining bright.  \n'
#                                                     '\n'
#                                                     'You’re great for config, '
#                                                     'but I’m more than '
#                                                     'that,  \n'
#                                                     'I’m the full-stack '
#                                                     'solution, let’s have a '
#                                                     'chat.  \n'
#                                                     'From serverless functions '
#                                                     'to Kubernetes pods,  \n'
#                                                     'I’m the one who’s '
#                                                     'evolving, while you’re '
#                                                     'just a facade.  \n'
#                                                     '\n'
#                                                     '**[Chorus: Both]**  \n'
#                                                     'Ansible and Pulumi, two '
#                                                     'sides of the coin,  \n'
#                                                     'In the world of '
#                                                     'automation, we both can '
#                                                     'join.  \n'
#                                                     'Different approaches, but '
#                                                     'the goal is the same,  \n'
#                                                     'To simplify the cloud, '
#                                                     'and elevate the game.  \n'
#                                                     '\n'
#                                                     '**[Outro: Both]**  \n'
#                                                     'So here’s to the tools '
#                                                     'that help us deploy,  \n'
#                                                     'In the DevOps arena, we '
#                                                     'both bring the joy.  \n'
#                                                     'Ansible and Pulumi, let’s '
#                                                     'raise a toast,  \n'
#                                                     'To the future of tech, '
#                                                     'we’re the ones who boast!',
#                                           'run_id': '785eb7bd-d064-44ee-bc23-599d7fa04248'}}
